# %% [markdown]
# <a href="https://colab.research.google.com/github/brahmandamsasanka/Practice/blob/main/20_Day_ML_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Goal - What is ML? Supervised vs. Unsupervised, train/test split
